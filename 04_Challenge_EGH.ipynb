# %%
import pandas as pd

# %%
ls -l
# Out:
# total 1015612
# -rw-rw-rw- 1 elsa elsa    130966 Dec 13 19:30 03_Challenge_EGH.ipynb
# -rw-rw-rw- 1 elsa elsa    496409 Dec 10 19:33 03_Challenge_prueba_EGH.ipynb
# -rw-rw-rw- 1 elsa elsa      1011 Dec 13 20:14 04_Challenge_EGH.ipynb
# -rw-rw-rw- 1 elsa elsa    286114 Dec 10 20:56 04_Challenge_prueba_EGH.ipynb
# -rw-rw-rw- 1 elsa elsa     21796 Dec 13 17:34 05_Challenge_EGH.ipynb
# -rw-rw-rw- 1 elsa elsa      7827 Dec 13 17:32 05_Challenge_b_EGH.ipynb
# -rw-rw-rw- 1 elsa elsa 554970628 Dec 10 18:23 bookings.csv.bz2
# -rw-rw-rw- 1 elsa elsa    535893 Dec 10 20:07 bookings.sample.csv.bz2
# -rw-rw-rw- 1 elsa elsa 483188920 Dec 10 18:23 searches.csv.bz2
# -rw-rw-rw- 1 elsa elsa    244720 Dec 10 18:39 searches.sample.csv.bz2
# -rw-rw-rw- 1 elsa elsa     77871 Dec 13 17:24 top_airports.csv

# %%
bc=pd.read_csv('./bookings.csv.bz2', sep='^', chunksize = 500000, low_memory=False, dtype=str)

all_chunks=pd.DataFrame()
for i, chunk in enumerate(bc):
    all_chunks=all_chunks.append(chunk)
    all_chunks.drop_duplicates(inplace=True)
    print(i*500000, len(all_chunks))
    
all_chunks.to_csv('bookings_no_dup.csv', sep='^', index=False)
! bzip2 -f bookings_no_dup.csv

# a la izquierda son los que ha leido y a la derecha los que no son duplicados
# Out:
# 0 500000
# 500000 1000000
# 1000000 1000000
# 1500000 1000000
# 2000000 1000000
# 2500000 1000000
# 3000000 1000000
# 3500000 1000000
# 4000000 1000000
# 4500000 1000000
# 5000000 1000003
# 5500000 1000003
# 6000000 1000003
# 6500000 1000003
# 7000000 1000003
# 7500000 1000003
# 8000000 1000003
# 8500000 1000003
# 9000000 1000003
# 9500000 1000003
# 10000000 1000003

# %%
# %%time
bc=pd.read_csv('./searches.csv.bz2', sep='^', chunksize = 500000, low_memory=False, dtype=str)

all_chunks=pd.DataFrame()
for i, chunk in enumerate(bc):
    all_chunks=all_chunks.append(chunk)
    all_chunks.drop_duplicates(inplace=True)
    print(i*500000, len(all_chunks))
    
all_chunks.to_csv('searches_no_dup.csv', sep='^', index=False)
! bzip2 -f searches_no_dup.csv
# Out:
# 0 358999
# 500000 358999
# 1000000 359003
# 1500000 359003
# 2000000 359003
# 2500000 359003
# 3000000 359003
# 3500000 359003
# 4000000 359003
# 4500000 359003
# 5000000 359003
# 5500000 359003
# 6000000 359003
# 6500000 359003
# 7000000 359003
# 7500000 359003
# 8000000 359003
# 8500000 359003
# 9000000 359003
# 9500000 359003
# 10000000 359003
# 10500000 359003
# 11000000 359003
# 11500000 359003
# 12000000 359003
# 12500000 359003
# 13000000 359003
# 13500000 359003
# 14000000 359003
# 14500000 359003
# 15000000 359003
# 15500000 359003
# 16000000 359003
# 16500000 359003
# 17000000 359003
# 17500000 359003
# 18000000 359003
# 18500000 359003
# 19000000 359003
# 19500000 359003
# 20000000 359004
# CPU times: user 7min 3s, sys: 48.6 s, total: 7min 51s
# Wall time: 6min 28s

# %%
#Action plan:
# Remove duplicates
# read 3 columns from bookings and all from searches
# remove white spaces from bookings dep/arr
# remove duplicates from booking
# save index from the file
# create column 'booked' with 1 in bookings table
# merge on 3 columns
# fill 'booked' of merged table with with 0
# merge with file data over index

# %%
b = pd.read_csv('bookings_no_dup.csv.bz2', sep='^',low_memory=False, nrows=1000)
b.columns.tolist()
# Out:
# ['act_date           ',
#  'source',
#  'pos_ctry',
#  'pos_iata',
#  'pos_oid  ',
#  'rloc          ',
#  'cre_date           ',
#  'duration',
#  'distance',
#  'dep_port',
#  'dep_city',
#  'dep_ctry',
#  'arr_port',
#  'arr_city',
#  'arr_ctry',
#  'lst_port',
#  'lst_city',
#  'lst_ctry',
#  'brd_port',
#  'brd_city',
#  'brd_ctry',
#  'off_port',
#  'off_city',
#  'off_ctry',
#  'mkt_port',
#  'mkt_city',
#  'mkt_ctry',
#  'intl',
#  'route          ',
#  'carrier',
#  'bkg_class',
#  'cab_class',
#  'brd_time           ',
#  'off_time           ',
#  'pax',
#  'year',
#  'month',
#  'oid      ']

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
# s = pd.read_csv('searches_no_dup.csv.bz2', sep='^', usecols=['Date','Origin','Destination'])
s = pd.read_csv('searches_no_dup.csv.bz2', sep='^')
b = pd.read_csv('bookings_no_dup.csv.bz2', sep='^', usecols=['cre_date           ','dep_port','arr_port'])
b.columns=b.columns.str.strip()
b.dep_port=b.dep_port.str.strip()
b.arr_port=b.arr_port.str.strip()
b.cre_date=b.cre_date.str[0:10]

# %%
b.head()
# Out:
#      cre_date dep_port arr_port
# 0  2013-02-22      ZRH      LHR
# 1  2013-03-26      SAL      CLT
# 2  2013-03-26      SAL      CLT
# 3  2013-03-26      AKL      SVO
# 4  2013-03-26      AKL      SVO

# %%
s.head()
# Out:
#          Date Origin Destination
# 0  2013-01-01    TXL         AUH
# 1  2013-01-01    ATH         MIL
# 2  2013-01-01    ICT         SFO
# 3  2013-01-01    RNB         ARN
# 4  2013-01-01    OSL         MAD

# %%
print(len(b))
b.drop_duplicates(inplace=True)
print(len(b))
# Out:
# 1000003
# 334876

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
# s = pd.read_csv('searches_no_dup.csv.bz2', sep='^', usecols=['Date','Origin','Destination'])
s = pd.read_csv('searches_no_dup.csv.bz2', sep='^', low_memory=False)
b = pd.read_csv('bookings_no_dup.csv.bz2', sep='^', usecols=['cre_date           ','dep_port','arr_port'])
b.columns=b.columns.str.strip()
b.dep_port=b.dep_port.str.strip()
b.arr_port=b.arr_port.str.strip()
b.cre_date=b.cre_date.str[0:10]
b.drop_duplicates(inplace=True)
b['booked']=1

# %%
b.head()
# Out:
#      cre_date dep_port arr_port  booked
# 0  2013-02-22      ZRH      LHR       1
# 1  2013-03-26      SAL      CLT       1
# 3  2013-03-26      AKL      SVO       1
# 5  2013-03-20      DEN      LGA       1
# 7  2013-03-25      NRT      SIN       1

# %%
s.head()
# Out:
#          Date      Time TxnCode                          OfficeID Country  \
# 0  2013-01-01  20:25:57     MPT  624d8c3ac0b3a7ca03e3c167e0f48327      DE
# 1  2013-01-01  10:15:33     MPT  b0af35b31588dc4ab06d5cf2986e8e02      MD
# 2  2013-01-01  18:04:49     MPT  3561a60621de06ab1badc8ca55699ef3      US
# 3  2013-01-01  17:42:40     FXP  1864e5e8013d9414150e91d26b6a558b      SE
# 4  2013-01-01  17:48:29     MPT  1ec336348f44207d2e0027dc3a68c118      NO
#
#   Origin Destination  RoundTrip  NbSegments Seg1Departure Seg1Arrival  \
# 0    TXL         AUH        1.0         2.0           TXL         AUH
# 1    ATH         MIL        0.0         1.0           ATH         MIL
# 2    ICT         SFO        1.0         2.0           ICT         SFO
# 3    RNB         ARN        0.0         1.0           RNB         ARN
# 4    OSL         MAD        1.0         2.0           OSL         MAD
#
#      Seg1Date Seg1Carrier Seg1BookingCode Seg2Departure Seg2Arrival  \
# ...

# %%
# tenemos que meter al final de s una columna más

# %%
s_b=s.merge(b, how='left', left_on=['Date','Origin','Destination'], right_on=['cre_date','dep_port','arr_port'])

# %%
len(s_b)
# tiene que haber el mismo numeoro de lineas antes y despues
# Out:
# 359004

# %%
s_b.head()
# Out:
#          Date      Time TxnCode                          OfficeID Country  \
# 0  2013-01-01  20:25:57     MPT  624d8c3ac0b3a7ca03e3c167e0f48327      DE
# 1  2013-01-01  10:15:33     MPT  b0af35b31588dc4ab06d5cf2986e8e02      MD
# 2  2013-01-01  18:04:49     MPT  3561a60621de06ab1badc8ca55699ef3      US
# 3  2013-01-01  17:42:40     FXP  1864e5e8013d9414150e91d26b6a558b      SE
# 4  2013-01-01  17:48:29     MPT  1ec336348f44207d2e0027dc3a68c118      NO
#
#   Origin Destination  RoundTrip  NbSegments Seg1Departure Seg1Arrival  \
# 0    TXL         AUH        1.0         2.0           TXL         AUH
# 1    ATH         MIL        0.0         1.0           ATH         MIL
# 2    ICT         SFO        1.0         2.0           ICT         SFO
# 3    RNB         ARN        0.0         1.0           RNB         ARN
# 4    OSL         MAD        1.0         2.0           OSL         MAD
#
#      Seg1Date Seg1Carrier Seg1BookingCode Seg2Departure Seg2Arrival  \
# ...

# %%
s_b.drop(['cre_date','dep_port','arr_port'], axis=1, inplace=True)

# %%
s_b.tail()
# Out:
#                                                      Date      Time TxnCode  \
# 358999                                         2013-01-01  20:25:57     MPT
# 359000  2013-01-01,10:15:33,MPT,b0af35b31588dc4ab06d5c...       NaN     NaN
# 359001                                         2013-01-01  18:04:49     MPT
# 359002                                         2013-01-01  19:57:57     MPT
# 359003                                         2013-10-13  18:57:54     MTP
#
#                                 OfficeID Country Origin Destination  \
# 358999  624d8c3ac0b3a7ca03e3c167e0f48327      DE    TXL         AUH
# 359000                               NaN     NaN    NaN         NaN
# 359001                              3561      US    ICT         SFO
# 359002  28d7a8c95e4db88589d3d35b66920e78      DE    FRA         BGW
# 359003  e41c9d833aa74600552f2ed688b67d81      AT    VIE          HA
#
#         RoundTrip  NbSegments Seg1Departure Seg1Arrival    Seg1Date  \
# ...

# %%
s_b[ s_b['booked']>0].head()
# así vemos si hay 1
# Out:
#            Date      Time TxnCode                          OfficeID Country  \
# 27   2013-01-01  18:33:28     CCP  3565e31495ecfd46fa018339d20382b1      SA
# 40   2013-01-01  06:36:57     FFP  86f167b84e77346849f9439ae87c02a6      SA
# 59   2013-01-01  07:00:38     FQD  e8741eaf2fa2f71f931475d18fa72096      US
# 134  2013-01-01  23:30:44     MPT  5215502d9524c3183f3839b0d9a5e4f9      AU
# 172  2013-01-01  18:34:27     MPT  fd4afff0035bec8f8e305d38804c33f6      IN
#
#     Origin Destination  RoundTrip  NbSegments Seg1Departure Seg1Arrival  \
# 27     RUH         JED        0.0         1.0           RUH         JED
# 40     DMM         MNL        1.0         2.0           DMM         MNL
# 59     ATL         MIA        0.0         1.0           ATL         MIA
# 134    MEL         SYD        0.0         1.0           MEL         SYD
# 172    BOM         JED        1.0         2.0           BOM         JED
#
#        Seg1Date Seg1Carrier Seg1BookingCode Seg2Departure Seg2Arrival  \
# ...

# %%
s_b['booked']=s_b['booked'].fillna(0)

# %%
s_b=s_b.astype({'booked':int})

# %%
s_b.tail(3)
# Out:
#               Date      Time TxnCode                          OfficeID  \
# 359001  2013-01-01  18:04:49     MPT                              3561
# 359002  2013-01-01  19:57:57     MPT  28d7a8c95e4db88589d3d35b66920e78
# 359003  2013-10-13  18:57:54     MTP  e41c9d833aa74600552f2ed688b67d81
#
#        Country Origin Destination  RoundTrip  NbSegments Seg1Departure  \
# 359001      US    ICT         SFO        1.0         2.0           ICT
# 359002      DE    FRA         BGW        1.0         2.0           FRA
# 359003      AT    VIE          HA        NaN         NaN           NaN
#
#        Seg1Arrival    Seg1Date Seg1Carrier Seg1BookingCode Seg2Departure  \
# 359001         SFO  2013-08-02         NaN             NaN           SFO
# 359002         BGW  2013-02-26         NaN             NaN           BGW
# 359003         NaN         NaN         NaN             NaN           NaN
#
#        Seg2Arrival    Seg2Date Seg2Carrier Seg2BookingCode Seg3Departure  \
# ...

# %%
s_b.to_csv("searches_with_book", sep='^', index=False)
