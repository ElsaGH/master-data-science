# %% [markdown]
# # Data Aggregation and Group Operations

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## GroupBy mechanics

# %%
nrows = 10
df = pd.DataFrame({'company' : np.random.choice(list('ab'), nrows),
                  'data1' : np.random.randn(nrows) * 50 + 100,
                  'city' : np.random.choice(list('MP'), nrows),
                  'income' : np.random.randn(nrows) * 30000 + 50000 })
df
# Out:
#   company       data1 city        income
# 0       a  148.300038    P  65670.905071
# 1       b   89.662323    M -10450.256993
# 2       a   55.600361    M  78985.252627
# 3       a   78.278191    P  17303.704310
# 4       a  112.505657    P  15087.119461
# 5       b  124.488859    P  64915.470065
# 6       a   85.665046    M  69404.493051
# 7       b   41.532992    M  18435.031493
# 8       a  103.322088    M -18031.199879
# 9       a  173.747477    P  -7809.941479

# %%
grouped = df.groupby('company')
grouped

# %%
grouped.sum()
# Out:
#               data1         income
# company
# a        757.418858  220610.333162
# b        255.684175   72900.244565

# %%
grouped.mean()
# Out:
#               data1        income
# company
# a        108.202694  31515.761880
# b         85.228058  24300.081522

# %%
grouped.min()
# Out:
#              data1 city        income
# company
# a        55.600361    M -18031.199879
# b        41.532992    M -10450.256993

# %% [markdown]
# ### Iterating over groups

# %%
for name, group in df.groupby('company'):
    print(name)
# Out:
# a
# b

# %%
for name, group in df.groupby('company'):
    print(group)
# Out:
#   company       data1 city        income
# 0       a  148.300038    P  65670.905071
# 2       a   55.600361    M  78985.252627
# 3       a   78.278191    P  17303.704310
# 4       a  112.505657    P  15087.119461
# 6       a   85.665046    M  69404.493051
# 8       a  103.322088    M -18031.199879
# 9       a  173.747477    P  -7809.941479
#   company       data1 city        income
# 1       b   89.662323    M -10450.256993
# 5       b  124.488859    P  64915.470065
# 7       b   41.532992    M  18435.031493

# %%
dict(list(df.groupby('company')))
# tenemos todos los datos separados en dataframes
# Out:
# {'a':   company       data1 city        income
#  0       a  148.300038    P  65670.905071
#  2       a   55.600361    M  78985.252627
#  3       a   78.278191    P  17303.704310
#  4       a  112.505657    P  15087.119461
#  6       a   85.665046    M  69404.493051
#  8       a  103.322088    M -18031.199879
#  9       a  173.747477    P  -7809.941479,
#  'b':   company       data1 city        income
#  1       b   89.662323    M -10450.256993
#  5       b  124.488859    P  64915.470065
#  7       b   41.532992    M  18435.031493}

# %%
all_data = dict(list(df.groupby('company')))
all_data['a']
# Out:
#   company       data1 city        income
# 0       a  148.300038    P  65670.905071
# 2       a   55.600361    M  78985.252627
# 3       a   78.278191    P  17303.704310
# 4       a  112.505657    P  15087.119461
# 6       a   85.665046    M  69404.493051
# 8       a  103.322088    M -18031.199879
# 9       a  173.747477    P  -7809.941479

# %% [markdown]
# ### Selecting a column or subset of columns

# %% [raw]
# df.groupby('key1')['data1']
# df.groupby('key1')[['data2']]

# %% [raw]
# df['data1'].groupby(df['key1'])
# df[['data2']].groupby(df['key1'])

# %%
df.groupby(['company','city']).mean()
# Out:
#                    data1        income
# company city
# a       M      81.529165  43452.848600
#         P     128.207841  22562.946841
# b       M      65.597658   3992.387250
#         P     124.488859  64915.470065

# %%
df.groupby(['company','city']).mean()['income']
# con este perdemos tiempo en calcular todas las medias
# Out:
# company  city
# a        M       43452.848600
#          P       22562.946841
# b        M        3992.387250
#          P       64915.470065
# Name: income, dtype: float64

# %%
means = df.groupby(['company','city'])['income'].mean()
# company y city son indices, es un multi index

# %%
means
# Out:
# company  city
# a        M       43452.848600
#          P       22562.946841
# b        M        3992.387250
#          P       64915.470065
# Name: income, dtype: float64

# %%
means['a','P']
# Out:
# 22562.946840739576

# %%
means.index
# Out:
# MultiIndex([('a', 'M'),
#             ('a', 'P'),
#             ('b', 'M'),
#             ('b', 'P')],
#            names=['company', 'city'])

# %%
means.reset_index()
# Out:
#   company city        income
# 0       a    M  43452.848600
# 1       a    P  22562.946841
# 2       b    M   3992.387250
# 3       b    P  64915.470065

# %%
df.groupby('company')[['data1','city']].max()
# Out:
#               data1 city
# company
# a        173.747477    P
# b        124.488859    P

# %% [markdown]
# ## Data aggregation

# %%
df.groupby('city').sum()
# Out:
#            data1         income
# city
# M     375.782810  138343.320299
# P     637.320222  155167.257428

# %%
df.groupby('city').median()
# Out:
#            data1        income
# city
# M      85.665046  18435.031493
# P     124.488859  17303.704310

# %%
df.groupby('city').quantile(.9)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-a0df85a72157> in <module>
# ----> 1 df.groupby('city').quantile(.9)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in quantile(self, q, interpolation)
#    1912                 post_processing=post_processor,
#    1913                 q=q,
# -> 1914                 interpolation=interpolation,
#    1915             )
#    1916         else:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _get_cythonized_result(self, how, grouper, aggregate, cython_dtype, needs_values, needs_mask, needs_ngroups, result_is_index, pre_processing, post_processing, **kwargs)
#    2280                 vals = obj.values
#    2281                 if pre_processing:
# -> 2282                     vals, inferences = pre_processing(vals)
#    2283                 func = partial(func, vals)
#    2284
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in pre_processor(vals)
#    1878             if is_object_dtype(vals):
#    1879                 raise TypeError(
# -> 1880                     "'quantile' cannot be performed against " "'object' dtypes!"
#    1881                 )
#    1882
#
# TypeError: 'quantile' cannot be performed against 'object' dtypes!

# %%
stats = df.groupby('city').describe()
stats
# Out:
#      data1                                                            \
#      count        mean        std        min         25%         50%
# city
# M      5.0   75.156562  25.627776  41.532992   55.600361   85.665046
# P      5.0  127.464044  36.152967  78.278191  112.505657  124.488859
#
#                              income                                            \
#              75%         max  count          mean           std           min
# city
# M      89.662323  103.322088    5.0  27668.664060  44727.120856 -18031.199879
# P     148.300038  173.747477    5.0  31033.451486  32784.695413  -7809.941479
#
#
#                25%           50%           75%           max
# city
# M    -10450.256993  18435.031493  69404.493051  78985.252627
# P     15087.119461  17303.704310  64915.470065  65670.905071

# %%
stats['data1']
# Out:
#       count        mean        std        min         25%         50%  \
# city
# M       5.0   75.156562  25.627776  41.532992   55.600361   85.665046
# P       5.0  127.464044  36.152967  78.278191  112.505657  124.488859
#
#              75%         max
# city
# M      89.662323  103.322088
# P     148.300038  173.747477

# %%
stats['data1','mean']
# Out:
# city
# M     75.156562
# P    127.464044
# Name: (data1, mean), dtype: float64

# %%
stats.columns
# Out:
# MultiIndex([( 'data1', 'count'),
#             ( 'data1',  'mean'),
#             ( 'data1',   'std'),
#             ( 'data1',   'min'),
#             ( 'data1',   '25%'),
#             ( 'data1',   '50%'),
#             ( 'data1',   '75%'),
#             ( 'data1',   'max'),
#             ('income', 'count'),
#             ('income',  'mean'),
#             ('income',   'std'),
#             ('income',   'min'),
#             ('income',   '25%'),
#             ('income',   '50%'),
#             ('income',   '75%'),
#             ('income',   'max')],
#            )

# %%
# !wget https://raw.githubusercontent.com/wesm/pydata-book/1st-edition/ch08/tips.csv
# con el ! se manda al terminal
# Out:
# --2019-11-22 21:20:29--  https://raw.githubusercontent.com/wesm/pydata-book/1st-edition/ch08/tips.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.132.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.132.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7943 (7.8K) [text/plain]
# Saving to: ‘tips.csv’
#
# tips.csv            100%[===================>]   7.76K  --.-KB/s    in 0.001s
#
# 2019-11-22 21:20:29 (11.7 MB/s) - ‘tips.csv’ saved [7943/7943]

# %%
tips = pd.read_csv('tips.csv')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['tip_pct'] = tips['tip'] / tips['total_bill']
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size   tip_pct
# 0       16.99  1.01  Female     No  Sun  Dinner     2  0.059447
# 1       10.34  1.66    Male     No  Sun  Dinner     3  0.160542
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.166587
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.139780
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.146808

# %% [markdown]
# ### Column-wise and multiple function application

# %%
tips.groupby('sex').mean()
# Out:
#         total_bill       tip      size   tip_pct
# sex
# Female   18.056897  2.833448  2.459770  0.166491
# Male     20.744076  3.089618  2.630573  0.157651

# %%
tips.groupby('sex').std()
# Out:
#         total_bill       tip      size   tip_pct
# sex
# Female    8.009209  1.159495  0.937644  0.053632
# Male      9.246469  1.489102  0.955997  0.064778

# %%
tips.groupby('sex').agg(['mean','std'])
# Out:
#        total_bill                 tip                size             tip_pct  \
#              mean       std      mean       std      mean       std      mean
# sex
# Female  18.056897  8.009209  2.833448  1.159495  2.459770  0.937644  0.166491
# Male    20.744076  9.246469  3.089618  1.489102  2.630573  0.955997  0.157651
#
#
#              std
# sex
# Female  0.053632
# Male    0.064778

# %%
tips.groupby(['sex', 'smoker']).agg(['mean','std', 'count'])
# Out:
#               total_bill                       tip                      size  \
#                     mean       std count      mean       std count      mean
# sex    smoker
# Female No      18.105185  7.286455    54  2.773519  1.128425    54  2.592593
#        Yes     17.977879  9.189751    33  2.931515  1.219916    33  2.242424
# Male   No      19.791237  8.726566    97  3.113402  1.489559    97  2.711340
#        Yes     22.284500  9.911845    60  3.051167  1.500120    60  2.500000
#
#                                 tip_pct
#                     std count      mean       std count
# sex    smoker
# Female No      1.073146    54  0.156921  0.036421    54
#        Yes     0.613917    33  0.182150  0.071595    33
# Male   No      0.989094    97  0.160669  0.041849    97
#        Yes     0.892530    60  0.152771  0.090588    60

# %%
tips.groupby(['sex', 'smoker']).agg([np.mean, np.std, np.count_nonzero])
# Out:
#               total_bill                               tip            \
#                     mean       std count_nonzero      mean       std
# sex    smoker
# Female No      18.105185  7.286455          54.0  2.773519  1.128425
#        Yes     17.977879  9.189751          33.0  2.931515  1.219916
# Male   No      19.791237  8.726566          97.0  3.113402  1.489559
#        Yes     22.284500  9.911845          60.0  3.051167  1.500120
#
#                                  size                           tip_pct  \
#               count_nonzero      mean       std count_nonzero      mean
# sex    smoker
# Female No              54.0  2.592593  1.073146            54  0.156921
#        Yes             33.0  2.242424  0.613917            33  0.182150
# Male   No              97.0  2.711340  0.989094            97  0.160669
#        Yes             60.0  2.500000  0.892530            60  0.152771
#
#
#                     std count_nonzero
# sex    smoker
# Female No      0.036421          54.0
#        Yes     0.071595          33.0
# Male   No      0.041849          97.0
#        Yes     0.090588          60.0

# %%
def minimax(series):
    return series.max() - series.min()
tips.groupby(['sex', 'smoker']).agg([np.mean, np.std, minimax])
# Out:
#               total_bill                         tip                    \
#                     mean       std minimax      mean       std minimax
# sex    smoker
# Female No      18.105185  7.286455   28.58  2.773519  1.128425    4.20
#        Yes     17.977879  9.189751   41.23  2.931515  1.219916    5.50
# Male   No      19.791237  8.726566   40.82  3.113402  1.489559    7.75
#        Yes     22.284500  9.911845   43.56  3.051167  1.500120    9.00
#
#                    size                     tip_pct
#                    mean       std minimax      mean       std   minimax
# sex    smoker
# Female No      2.592593  1.073146       5  0.156921  0.036421  0.195876
#        Yes     2.242424  0.613917       3  0.182150  0.071595  0.360233
# Male   No      2.711340  0.989094       4  0.160669  0.041849  0.220186
#        Yes     2.500000  0.892530       4  0.152771  0.090588  0.674707

# %%
tips.groupby(['sex', 'smoker']).agg({'total_bill' : [np.sum, np.mean],
                                     'tip' : [minimax, np.std]})
# Out:
#               total_bill                tip
#                      sum       mean minimax       std
# sex    smoker
# Female No         977.68  18.105185    4.20  1.128425
#        Yes        593.27  17.977879    5.50  1.219916
# Male   No        1919.75  19.791237    7.75  1.489559
#        Yes       1337.07  22.284500    9.00  1.500120

# %% [markdown]
# ## Group-wise operations and transformations

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size   tip_pct
# 0         16.99  1.01  Female     No   Sun  Dinner     2  0.059447
# 1         10.34  1.66    Male     No   Sun  Dinner     3  0.160542
# 2         21.01  3.50    Male     No   Sun  Dinner     3  0.166587
# 3         23.68  3.31    Male     No   Sun  Dinner     2  0.139780
# 4         24.59  3.61  Female     No   Sun  Dinner     4  0.146808
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  0.203927
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  0.073584
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  0.088222
# 242       17.82  1.75    Male     No   Sat  Dinner     2  0.098204
# 243       18.78  3.00  Female     No  Thur  Dinner     2  0.159744
#
# [244 rows x 8 columns]

# %%
tips_by_smoker = tips.groupby('smoker')['tip_pct'].agg([np.mean, np.std])
tips_by_smoker
# Out:
#             mean       std
# smoker
# No      0.159328  0.039910
# Yes     0.163196  0.085119

# %%
merged = tips.merge(tips_by_smoker, left_on='smoker', right_index=True)
merged.head()
# cuando hacemos un groupby el criterio que aplicamos queda como el indice
******
# Out:
#    total_bill   tip     sex smoker  day    time  size   tip_pct      mean  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2  0.059447  0.159328
# 1       10.34  1.66    Male     No  Sun  Dinner     3  0.160542  0.159328
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.166587  0.159328
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.139780  0.159328
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.146808  0.159328
#
#        std
# 0  0.03991
# 1  0.03991
# 2  0.03991
# 3  0.03991
# 4  0.03991

# %% [markdown]
# ### Apply: General split-apply-combine

# %%
def top(df, n=5, col='tip_pct'):
    return df.sort_values(by=col, ascending=False).head(n)
top(merged)
# Out:
#      total_bill   tip     sex smoker  day    time  size   tip_pct      mean  \
# 172        7.25  5.15    Male    Yes  Sun  Dinner     2  0.710345  0.163196
# 178        9.60  4.00  Female    Yes  Sun  Dinner     2  0.416667  0.163196
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1  0.325733  0.163196
# 232       11.61  3.39    Male     No  Sat  Dinner     2  0.291990  0.159328
# 183       23.17  6.50    Male    Yes  Sun  Dinner     4  0.280535  0.163196
#
#           std
# 172  0.085119
# 178  0.085119
# 67   0.085119
# 232  0.039910
# 183  0.085119

# %%
merged.groupby('sex').apply(top)
# saca el top 5 de registro de cada grupo, top 5 de chicas y top 5 de chicos
# Out:
#             total_bill   tip     sex smoker   day    time  size   tip_pct  \
# sex
# Female 178        9.60  4.00  Female    Yes   Sun  Dinner     2  0.416667
#        67         3.07  1.00  Female    Yes   Sat  Dinner     1  0.325733
#        109       14.31  4.00  Female    Yes   Sat  Dinner     2  0.279525
#        93        16.32  4.30  Female    Yes   Fri  Dinner     2  0.263480
#        221       13.42  3.48  Female    Yes   Fri   Lunch     2  0.259314
# Male   172        7.25  5.15    Male    Yes   Sun  Dinner     2  0.710345
#        232       11.61  3.39    Male     No   Sat  Dinner     2  0.291990
#        183       23.17  6.50    Male    Yes   Sun  Dinner     4  0.280535
#        149        7.51  2.00    Male     No  Thur   Lunch     2  0.266312
#        181       23.33  5.65    Male    Yes   Sun  Dinner     2  0.242177
#
#                 mean       std
# sex
# Female 178  0.163196  0.085119
#        67   0.163196  0.085119
#        109  0.163196  0.085119
#        93   0.163196  0.085119
#        221  0.163196  0.085119
# Male   172  0.163196  0.085119
#        232  0.159328  0.039910
#        183  0.163196  0.085119
#        149  0.159328  0.039910
#        181  0.163196  0.085119

# %% [raw]
# f = lambda x: x.describe()
# grouped.apply(f)

# %% [markdown]
# #### Suppressing the group keys

# %%
tips.groupby(['sex', 'smoker'], group_keys=False).apply(top)
# Out:
#      total_bill   tip     sex smoker   day    time  size   tip_pct
# 51        10.29  2.60  Female     No   Sun  Dinner     2  0.252672
# 139       13.16  2.75  Female     No  Thur   Lunch     2  0.208967
# 18        16.97  3.50  Female     No   Sun  Dinner     3  0.206246
# 14        14.83  3.02  Female     No   Sun  Dinner     2  0.203641
# 115       17.31  3.50  Female     No   Sun  Dinner     2  0.202195
# 178        9.60  4.00  Female    Yes   Sun  Dinner     2  0.416667
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1  0.325733
# 109       14.31  4.00  Female    Yes   Sat  Dinner     2  0.279525
# 93        16.32  4.30  Female    Yes   Fri  Dinner     2  0.263480
# 221       13.42  3.48  Female    Yes   Fri   Lunch     2  0.259314
# 232       11.61  3.39    Male     No   Sat  Dinner     2  0.291990
# 149        7.51  2.00    Male     No  Thur   Lunch     2  0.266312
# 185       20.69  5.00    Male     No   Sun  Dinner     5  0.241663
# 88        24.71  5.85    Male     No  Thur   Lunch     2  0.236746
# 6          8.77  2.00    Male     No   Sun  Dinner     2  0.228050
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2  0.710345
# 183       23.17  6.50    Male    Yes   Sun  Dinner     4  0.280535
# 181       23.33  5.65    Male    Yes   Sun  Dinner     2  0.242177
# 194       16.58  4.00    Male    Yes  Thur   Lunch     2  0.241255
# 174       16.82  4.00    Male    Yes   Sun  Dinner     2  0.237812

# %% [markdown]
# ### Quantile and bucket analysis

# %%
pd.cut(merged['total_bill'], 5)
# no le decimos las fronteras, sino los trozos, nos lo va a cortar en 5
# Out:
# 0      (12.618, 22.166]
# 1       (3.022, 12.618]
# 2      (12.618, 22.166]
# 3      (22.166, 31.714]
# 4      (22.166, 31.714]
#              ...
# 234    (12.618, 22.166]
# 236     (3.022, 12.618]
# 237    (31.714, 41.262]
# 240    (22.166, 31.714]
# 241    (22.166, 31.714]
# Name: total_bill, Length: 244, dtype: category
# Categories (5, interval[float64]): [(3.022, 12.618] < (12.618, 22.166] < (22.166, 31.714] < (31.714, 41.262] < (41.262, 50.81]]

# %%
merged.groupby(pd.cut(merged['total_bill'], 5))['tip_pct'].agg([np.mean, np.std])
# Out:
#                       mean       std
# total_bill
# (3.022, 12.618]   0.190854  0.094609
# (12.618, 22.166]  0.163942  0.041264
# (22.166, 31.714]  0.143799  0.051131
# (31.714, 41.262]  0.121530  0.042792
# (41.262, 50.81]   0.125121  0.052650

# %%
merged['size'] > 2
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 234    False
# 236    False
# 237    False
# 240    False
# 241    False
# Name: size, Length: 244, dtype: bool

# %%
merged.groupby(merged['size'] > 2)['tip_pct'].agg([np.mean, np.std])
# Out:
#            mean       std
# size
# False  0.167009  0.067404
# True   0.148982  0.044730

# %% [markdown]
# ### Example: Filling missing values with group-specific values

# %% [markdown]
# ## Pivot tables and Cross-tabulation

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size   tip_pct
# 0         16.99  1.01  Female     No   Sun  Dinner     2  0.059447
# 1         10.34  1.66    Male     No   Sun  Dinner     3  0.160542
# 2         21.01  3.50    Male     No   Sun  Dinner     3  0.166587
# 3         23.68  3.31    Male     No   Sun  Dinner     2  0.139780
# 4         24.59  3.61  Female     No   Sun  Dinner     4  0.146808
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  0.203927
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  0.073584
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  0.088222
# 242       17.82  1.75    Male     No   Sat  Dinner     2  0.098204
# 243       18.78  3.00  Female     No  Thur  Dinner     2  0.159744
#
# [244 rows x 8 columns]

# %%
tips.pivot_table(index='size', columns='smoker', values='tip_pct')
# Out:
# smoker        No       Yes
# size
# 1       0.159829  0.274755
# 2       0.164996  0.166706
# 3       0.149671  0.157543
# 4       0.147604  0.142036
# 5       0.178415  0.086116
# 6       0.156229       NaN

# %%
tips.pivot_table(index='size', columns=['smoker','time'], values='tip_pct')
# se agregan por la media por defecto
# Out:
# smoker        No                 Yes
# time      Dinner     Lunch    Dinner     Lunch
# size
# 1       0.137931  0.181728  0.325733  0.223776
# 2       0.164383  0.166005  0.167246  0.165266
# 3       0.153705  0.118742  0.148061  0.204952
# 4       0.148737  0.138919  0.139064  0.155410
# 5       0.206928  0.121389  0.086116       NaN
# 6       0.103799  0.173706       NaN       NaN

# %%
tips.pivot_table(index='size', columns=['smoker','time'], values='total_bill', aggfunc='sum')
# Out:
# smoker      No             Yes
# time    Dinner   Lunch  Dinner   Lunch
# size
# 1         7.25   10.07    3.07    8.58
# 2       899.48  481.33  892.30  292.78
# 3       488.81   57.44  303.12   35.18
# 4       635.89   86.11  273.06   63.64
# 5        50.54   41.19   58.61     NaN
# 6        48.17   91.15     NaN     NaN
